# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'
import graphviz

# %%
# code2flow .\apaa\data\ --output "apaa_data.dot" --language=py
graphviz.Source.from_file("apaa_data.dot")

# %%
# code2flow .\apaa\learning\ --output "apaa_learning.dot" --language=py
graphviz.Source.from_file("apaa_learning.dot")

# %%
# code2flow .\apaa\preprocessing\ --output "apaa_preprocessing.dot" --language=py
graphviz.Source.from_file("apaa_preprocessing.dot")

# %%
# code2flow .\apaa --output "apaa.dot" --language=py
# apaa/helpers.py raises an error
graphviz.Source.from_file("apaa.dot")
